# %% [markdown]
# <a href="https://colab.research.google.com/github/totalcream/ktcloud_Genai/blob/main/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# basic_examples.py

print("=== 1. Hello World ===")
print("Hello, World!")

print("="*40)

print("=== 2. 변수와 자료형 ===")
name = "Alice"
age = 25
height = 165.5
print(f"이름: {name}, 나이: {age}, 키: {height}cm")

print("="*40)

print("=== 3. 조건문 (if-else) ===")
score = 85
if score >= 90:
    print("A학점")
elif score >= 80:
    print("B학점")
else:
    print("C학점 이하")

print("="*40)

print("=== 4. 반복문 (for) ===")
for i in range(1, 6):
    print(f"{i}번째 반복")

print("="*40)

print("=== 5. 리스트와 반복 ===")
fruits = ["사과", "바나나", "체리"]
for fruit in fruits:
    print(f"나는 {fruit}를 좋아해요!")

print("="*40)

print("=== 6. 함수 만들기 ===")
def add(a, b):
    return a + b

print(f"3 + 5 = {add(3, 5)}")

print("="*40)

print("=== 7. 딕셔너리 사용 ===")
student = {"이름": "승훈", "학번": 2025001, "학과": "전기전자공학"}
print(student["이름"])

print("="*40)

print("=== 8. 입력 받기 ===")
# input()은 실행 시 직접 입력해야 합니다.
# name_input = input("당신의 이름은 무엇인가요? ")
# print(f"반가워요, {name_input}님!")
print("실행 시 이름 입력을 받도록 되어있습니다. (주석 해제해서 사용하세요)")

print("="*40)

print("=== 9. 예외 처리 ===")
# try-except도 입력이 필요합니다.
# try:
#     num = int(input("숫자를 입력하세요: "))
#     print(f"두 배: {num * 2}")
# except ValueError:
#     print("숫자가 아닌 값을 입력했습니다!")
print("실행 시 숫자 입력을 받도록 되어있습니다. (주석 해제해서 사용하세요)")

print("="*40)

print("=== 10. 간단한 클래스 ===")
class Animal:
    def __init__(self, name):
        self.name = name

    def speak(self):
        print(f"{self.name}가 소리를 냅니다!")

dog = Animal("강아지")
dog.speak()

print("="*40)
print("모든 예제가 끝났습니다!")
# Out:
# === 1. Hello World ===
# Hello, World!
# ...
# === 2. 변수와 자료형 ===
# 이름: Alice, 나이: 25, 키: 165.5cm
# ...
# === 3. 조건문 (if-else) ===
# B학점
# ...
# === 4. 반복문 (for) ===
# 1번째 반복
# 2번째 반복
# 3번째 반복
# 4번째 반복
# 5번째 반복
# ...
# === 5. 리스트와 반복 ===
# 나는 사과를 좋아해요!
# 나는 바나나를 좋아해요!
# 나는 체리를 좋아해요!
# ...
# === 6. 함수 만들기 ===
# 3 + 5 = 8
# ...
# === 7. 딕셔너리 사용 ===
# 승훈
# ...
# === 8. 입력 받기 ===
# 실행 시 이름 입력을 받도록 되어있습니다. (주석 해제해서 사용하세요)
# ...
# === 9. 예외 처리 ===
# 실행 시 숫자 입력을 받도록 되어있습니다. (주석 해제해서 사용하세요)
# ...
# === 10. 간단한 클래스 ===
# 강아지가 소리를 냅니다!
# ...
# 모든 예제가 끝났습니다!
